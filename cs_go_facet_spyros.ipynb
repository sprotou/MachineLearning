# %%
setwd('C:\\Users\\sprot\\PycharmProjects\\ML452')

# %%
library(tidyverse)

# %%
masterData = read.csv('mm_master_demos.csv')

# %%
head(masterData)
# Out:
#   X file                                 map      date                  round
# 1 0 003201673717864202280_0171883906.dem de_dust2 09/28/2017 8:44:22 PM 1
# 2 1 003201673717864202280_0171883906.dem de_dust2 09/28/2017 8:44:22 PM 1
# 3 2 003201673717864202280_0171883906.dem de_dust2 09/28/2017 8:44:22 PM 1
# 4 3 003201673717864202280_0171883906.dem de_dust2 09/28/2017 8:44:22 PM 1
# 5 4 003201673717864202280_0171883906.dem de_dust2 09/28/2017 8:44:22 PM 1
# 6 5 003201673717864202280_0171883906.dem de_dust2 09/28/2017 8:44:22 PM 1
#   tick seconds  att_team vic_team att_side         ... vic_id      vic_rank
# 1 8482 133.0582 Team 1   Team 2   CounterTerrorist ... 7.65612e+16 17
# 2 8600 134.9023 Team 1   Team 2   CounterTerrorist ... 7.65612e+16 17
# 3 8610 135.0586 Team 2   Team 1   Terrorist        ... 7.65612e+16 16
# 4 8624 135.2774 Team 1   Team 2   CounterTerrorist ... 7.65612e+16 17
# 5 8632 135.4024 Team 2   Team 1   Terrorist        ... 7.65612e+16 16
# ...

# %%
myPlot1 = ggplot(masterData) + geom_point(aes(x=seconds, y=ct_eq_val, color = round_type, shape=round_type),size = 0.1)
myPlot1
# Out:
# plot without title

# %%
myPlot1 +  facet_grid(round_type ~ .)
# Out:
# plot without title
