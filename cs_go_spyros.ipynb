# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
cd C:\Users\sprot\PycharmProjects\ML452
# Out:
# C:\Users\sprot\PycharmProjects\ML452

# %%
masterData = pd.read_csv('mm_master_demos.csv')

masterCorr = masterData.corr()
sb.heatmap(masterCorr)
plt.show()

# %%
from sklearn.model_selection import train_test_split
train, test = train_test_split(masterData, test_size=0.2)

# %%
#I read the chapter "Building good training sets" from the Python ML book, but was not sure how to apply these instructions
#to my own dataset
